# %%
import pandas as pd
df = pd.read_csv("./fahrzeug_preis.csv")
df.head()
# Out:
#    price  yearOfRegistration  powerPS  kilometer   model fuelType  \
# 0   1450                1997       75      90000  andere   benzin
# 1  13100                2005      280       5000    golf   benzin
# 2   4500                2008       87      90000   yaris   benzin
# 3   6000                2009      177     125000     3er   diesel
# 4   3990                1999      118      90000     3er   benzin
#
#                                              name
# 0          Toyota_Toyota_Starlet_1._Hand__TÜV_neu
# 1                        R32_tauschen_oder_kaufen
# 2                          Toyota_Yaris_1.3_VVT_i
# 3                      320_Alpinweiss_Kohlenstoff
# 4  BMW_318i_E46_+++_1._Hand_+++_Liebhaberfahrzeug

# %% [markdown]
# ## Daten  aufbereiten
# * One Hot Encoding durchführen
# * Unnötige Spalten verwerfen

# %%
df = pd.get_dummies(df, columns = ["fuelType"])
df =df.drop(labels=["fuelType_lpg"],axis = 1)
df =df.drop(labels=["model", "name"],axis = 1)

X = df[["price", "yearOfRegistration", "powerPS", "kilometer", 
        "fuelType_benzin", "fuelType_diesel", "fuelType_hybrid"]].values

df.head()
# Out:
#    price  yearOfRegistration  powerPS  kilometer  fuelType_benzin  \
# 0   1450                1997       75      90000                1
# 1  13100                2005      280       5000                1
# 2   4500                2008       87      90000                1
# 3   6000                2009      177     125000                0
# 4   3990                1999      118      90000                1
#
#    fuelType_diesel  fuelType_hybrid
# 0                0                0
# 1                0                0
# 2                0                0
# 3                1                0
# 4                0                0
